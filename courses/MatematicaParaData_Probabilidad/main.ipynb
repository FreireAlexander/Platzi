# %%
import numpy as np 
from numpy.random import binomial
from scipy.stats import binom
from math import factorial
import matplotlib.pyplot as plt

# %%
def my_binomial(k, n, p):
    return factorial(n)/(factorial(k)*factorial(n-k))*(p**k)*(1-p)**(n-k)

# %%
my_binomial(2,3,0.5)
# Out:
# 0.375

# %%
dist = binom(3, 0.5)
dist.pmf(2)
# Out:
# np.float64(0.3750000000000001)

# %% [markdown]
# Probabilidad de obtener 2 o menos caras:

# %%
from fractions import Fraction
sum = sum([my_binomial(i, 3, 0.5) for i in range(3)])
f = Fraction(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 from fractions import Fraction
# ----> 2 sum = sum([my_binomial(i, 3, 0.5) for i in range(3)])
#       3 f = Fraction(sum)
#
# TypeError: 'float' object is not callable

# %%
print(f)
# Out:
# 7/8

# %%
def plot_hist(num_trials):
    values = [0,1,2,3]
    arr = []
    for _ in range(num_trials):
        arr.append(binomial(3,0.5))
    
    dist_sim = np.unique(arr, return_counts=True)[1]/len(arr)
    dist_teorica = [binom(3, 0.5).pmf(k) for k in values]
    plt.bar(values, dist_sim, color='#00ff00', label='Simulada', hatch='/')
    plt.bar(values, dist_teorica, color='orange', alpha=0.5, label='Teorica')
    plt.title(f"Simulacion con {num_trials} experimentos")
    plt.legend()
    plt.show()


plot_hist(20)
plot_hist(300)
plot_hist(10000)
